# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
import re
from wordcloud import WordCloud
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from nltk import pos_tag
from nltk.tokenize import word_tokenize
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import warnings
import ast
warnings.filterwarnings("ignore")

# %%
df1=pd.read_csv(r"C:\Users\dell\Downloads\merged_data1 (1).csv")

# %%
df1.head(5)
# Out:
#           reviewer_name                                              title  \
# 0  GrandTour39221463627                              Hospitable experience
# 1                Ashish                     Awesome stay at Visnita county
# 2              Shailesh  Vismita County need to have a relook at the pr...
# 3         Pratham Gowda                                      Awesome staff
# 4         udayshankar b                                      Superb Resort
#
#                                               review  id
# 0  The ambience amidst nature was lovely and sere...   1
# 1  We stayed there for 3 days ..it's awesome expe...   1
# 2  The property is extremely pricey with respect ...   1
# 3  beautiful Vibes, the service staff extremely c...   1
# 4  Resort is Beutiful  with Lot's of Greenaries a...   1

# %%
df2=pd.read_excel(r"C:\Users\dell\Downloads\hotel info (1).xlsx")

# %%
df2
# Out:
#                             Hotel_name  \
# 0                       Vismita County
# 1                              Aadrika
# 2   Honeydewwz Exoticaa Hotel & Resort
# 3   The River Tern Lodge Jungle Lodges
# 4                            Kerehaklu
# 5            Treebo Trend Maharaja Inn
# 6                 Treebo Trend Sunrise
# 7                    Green wood Resort
# 8       Genx Crystal Inn Chikmangaluru
# 9               Kalgreen Valley Resort
# 10                 Good Earth Homestay
# 11                Silent Valley Resort
# 12               Chikmagalur Golf Club
#
#                                               Address  id
# 0   State Highway 64 Aladgudde Cross Baskal Road, ...   1
# 1   Milan Theatre Road Milan Theatre Annex, Chikma...   2
# 2   Hospete Tharikere Shimogga State Hwy Chickmang...   3
# 3   Near Bhadra Forest Area, Lakvalli, Chikmagalur...   4
# 4                          Aldur, Chikmagalur 577111    5
# 5   Indira Gandhi Road Next To Punjab National Ban...   6
# 6   Indira Gandhi Rd Srungar Circle, Opposite To M...   7
# 7   BB Hills Road Near, Inam Dattathreya Peeta, Ch...   8
# 8   Shankar Mutt Road, SH 57 Basavanahalli, Chikma...   9
# 9   Kalsapur Estate, Koppa Taluk, Chikmagalur 577126   10
# 10                  Mallandur Rd, Chikmagalur 577101   11
# 11  Thodlu, Kalasa-Kudremukh Road Kudremukh Road, ...  12
# 12                      Pb No 154, Chikmagalur 577101  13

# %%
merged_df = pd.merge(df1,df2,on='id',how='inner')

# %%
merged_df
# Out:
#              reviewer_name                                              title  \
# 0     GrandTour39221463627                              Hospitable experience
# 1                   Ashish                     Awesome stay at Visnita county
# 2                 Shailesh  Vismita County need to have a relook at the pr...
# 3            Pratham Gowda                                      Awesome staff
# 4            udayshankar b                                      Superb Resort
# ...                    ...                                                ...
# 2036    rohitprakashmathur                                     Nice and clean
# 2037                Hrkn B                        Neat hotel comfortable stay
# 2038             Rajbolmal                                    Value for money
# 2039            kkeshav357                                 awesome experience
# 2040                Asha S                    Pleasant and comfortable stay!!
#
#                                                  review  id  \
# 0     The ambience amidst nature was lovely and sere...   1
# 1     We stayed there for 3 days ..it's awesome expe...   1
# 2     The property is extremely pricey with respect ...   1
# 3     beautiful Vibes, the service staff extremely c...   1
# 4     Resort is Beutiful  with Lot's of Greenaries a...   1
# ...                                                 ...  ..
# 2036  Nice and clean property in central Chickmaglur...   9
# 2037  We stayed in the family suite...which was very...   9
# 2038  Pros : Good complimentary breakfast, in terms ...   9
# 2039  Hi CrystalInn Team,  It was nice to stay with ...   9
# 2040  We (family of four) stayed here in the mid of ...   9
#
#                           Hotel_name  \
# 0                     Vismita County
# 1                     Vismita County
# 2                     Vismita County
# 3                     Vismita County
# 4                     Vismita County
# ...                              ...
# 2036  Genx Crystal Inn Chikmangaluru
# 2037  Genx Crystal Inn Chikmangaluru
# 2038  Genx Crystal Inn Chikmangaluru
# 2039  Genx Crystal Inn Chikmangaluru
# 2040  Genx Crystal Inn Chikmangaluru
#
#                                                 Address
# 0     State Highway 64 Aladgudde Cross Baskal Road, ...
# 1     State Highway 64 Aladgudde Cross Baskal Road, ...
# 2     State Highway 64 Aladgudde Cross Baskal Road, ...
# 3     State Highway 64 Aladgudde Cross Baskal Road, ...
# 4     State Highway 64 Aladgudde Cross Baskal Road, ...
# ...                                                 ...
# 2036  Shankar Mutt Road, SH 57 Basavanahalli, Chikma...
# 2037  Shankar Mutt Road, SH 57 Basavanahalli, Chikma...
# 2038  Shankar Mutt Road, SH 57 Basavanahalli, Chikma...
# 2039  Shankar Mutt Road, SH 57 Basavanahalli, Chikma...
# 2040  Shankar Mutt Road, SH 57 Basavanahalli, Chikma...
#
# [2041 rows x 6 columns]

# %%
review = merged_df.drop(["reviewer_name","id","Address"],axis=1)

# %%
review
# Out:
#                                                   title  \
# 0                                 Hospitable experience
# 1                        Awesome stay at Visnita county
# 2     Vismita County need to have a relook at the pr...
# 3                                         Awesome staff
# 4                                         Superb Resort
# ...                                                 ...
# 2036                                     Nice and clean
# 2037                        Neat hotel comfortable stay
# 2038                                    Value for money
# 2039                                 awesome experience
# 2040                    Pleasant and comfortable stay!!
#
#                                                  review  \
# 0     The ambience amidst nature was lovely and sere...
# 1     We stayed there for 3 days ..it's awesome expe...
# 2     The property is extremely pricey with respect ...
# 3     beautiful Vibes, the service staff extremely c...
# 4     Resort is Beutiful  with Lot's of Greenaries a...
# ...                                                 ...
# 2036  Nice and clean property in central Chickmaglur...
# 2037  We stayed in the family suite...which was very...
# 2038  Pros : Good complimentary breakfast, in terms ...
# 2039  Hi CrystalInn Team,  It was nice to stay with ...
# 2040  We (family of four) stayed here in the mid of ...
#
#                           Hotel_name
# 0                     Vismita County
# 1                     Vismita County
# 2                     Vismita County
# 3                     Vismita County
# 4                     Vismita County
# ...                              ...
# 2036  Genx Crystal Inn Chikmangaluru
# 2037  Genx Crystal Inn Chikmangaluru
# 2038  Genx Crystal Inn Chikmangaluru
# 2039  Genx Crystal Inn Chikmangaluru
# 2040  Genx Crystal Inn Chikmangaluru
#
# [2041 rows x 3 columns]

# %%
review.isna().sum()
# Out:
# title         6
# review        6
# Hotel_name    0
# dtype: int64

# %%
review.dropna(inplace=True)

# %%
review
# Out:
#                                                   title  \
# 0                                 Hospitable experience
# 1                        Awesome stay at Visnita county
# 2     Vismita County need to have a relook at the pr...
# 3                                         Awesome staff
# 4                                         Superb Resort
# ...                                                 ...
# 2036                                     Nice and clean
# 2037                        Neat hotel comfortable stay
# 2038                                    Value for money
# 2039                                 awesome experience
# 2040                    Pleasant and comfortable stay!!
#
#                                                  review  \
# 0     The ambience amidst nature was lovely and sere...
# 1     We stayed there for 3 days ..it's awesome expe...
# 2     The property is extremely pricey with respect ...
# 3     beautiful Vibes, the service staff extremely c...
# 4     Resort is Beutiful  with Lot's of Greenaries a...
# ...                                                 ...
# 2036  Nice and clean property in central Chickmaglur...
# 2037  We stayed in the family suite...which was very...
# 2038  Pros : Good complimentary breakfast, in terms ...
# 2039  Hi CrystalInn Team,  It was nice to stay with ...
# 2040  We (family of four) stayed here in the mid of ...
#
#                           Hotel_name
# 0                     Vismita County
# 1                     Vismita County
# 2                     Vismita County
# 3                     Vismita County
# 4                     Vismita County
# ...                              ...
# 2036  Genx Crystal Inn Chikmangaluru
# 2037  Genx Crystal Inn Chikmangaluru
# 2038  Genx Crystal Inn Chikmangaluru
# 2039  Genx Crystal Inn Chikmangaluru
# 2040  Genx Crystal Inn Chikmangaluru
#
# [2035 rows x 3 columns]

# %%
#adding review+review title
review['review_new'] = review['title']+" "+review['review']

# %%
review
# Out:
#                                                   title  \
# 0                                 Hospitable experience
# 1                        Awesome stay at Visnita county
# 2     Vismita County need to have a relook at the pr...
# 3                                         Awesome staff
# 4                                         Superb Resort
# ...                                                 ...
# 2036                                     Nice and clean
# 2037                        Neat hotel comfortable stay
# 2038                                    Value for money
# 2039                                 awesome experience
# 2040                    Pleasant and comfortable stay!!
#
#                                                  review  \
# 0     The ambience amidst nature was lovely and sere...
# 1     We stayed there for 3 days ..it's awesome expe...
# 2     The property is extremely pricey with respect ...
# 3     beautiful Vibes, the service staff extremely c...
# 4     Resort is Beutiful  with Lot's of Greenaries a...
# ...                                                 ...
# 2036  Nice and clean property in central Chickmaglur...
# 2037  We stayed in the family suite...which was very...
# 2038  Pros : Good complimentary breakfast, in terms ...
# 2039  Hi CrystalInn Team,  It was nice to stay with ...
# 2040  We (family of four) stayed here in the mid of ...
#
#                           Hotel_name  \
# 0                     Vismita County
# 1                     Vismita County
# 2                     Vismita County
# 3                     Vismita County
# 4                     Vismita County
# ...                              ...
# 2036  Genx Crystal Inn Chikmangaluru
# 2037  Genx Crystal Inn Chikmangaluru
# 2038  Genx Crystal Inn Chikmangaluru
# 2039  Genx Crystal Inn Chikmangaluru
# 2040  Genx Crystal Inn Chikmangaluru
#
#                                              review_new
# 0     Hospitable experience The ambience amidst natu...
# 1     Awesome stay at Visnita county We stayed there...
# 2     Vismita County need to have a relook at the pr...
# 3     Awesome staff beautiful Vibes, the service sta...
# 4     Superb Resort Resort is Beutiful  with Lot's o...
# ...                                                 ...
# 2036  Nice and clean Nice and clean property in cent...
# 2037  Neat hotel comfortable stay We stayed in the f...
# 2038  Value for money Pros : Good complimentary brea...
# 2039  awesome experience Hi CrystalInn Team,  It was...
# 2040  Pleasant and comfortable stay!! We (family of ...
#
# [2035 rows x 4 columns]

# %%
review.Hotel_name.value_counts()
# Out:
# Vismita County                        457
# The River Tern Lodge Jungle Lodges    355
# Aadrika                               264
# Silent Valley Resort                  206
# Kerehaklu                             148
# Treebo Trend Sunrise                  112
# Honeydewwz Exoticaa Hotel & Resort    107
# Treebo Trend Maharaja Inn              98
# Kalgreen Valley Resort                 86
# Green wood Resort                      72
# Genx Crystal Inn Chikmangaluru         60
# Good Earth Homestay                    39
# Chikmagalur Golf Club                  31
# Name: Hotel_name, dtype: int64

# %%
review.describe()
# Out:
#             title                                             review  \
# count        2035                                               2035
# unique       1823                                               2035
# top     Excellent  The ambience amidst nature was lovely and sere...
# freq           16                                                  1
#
#             Hotel_name                                         review_new
# count             2035                                               2035
# unique              13                                               2035
# top     Vismita County  Hospitable experience The ambience amidst natu...
# freq               457                                                  1

# %%
#dropping duplicate rows
review.drop_duplicates()

#removing numbers and special characters from the review
def remove_numbers(text):
    pattern=r'[^A-z\s]'
    return re.sub(pattern, '',text).lower()
review['clean_review']=review.review_new.apply(remove_numbers)
review
# Out:
#                                                   title  \
# 0                                 Hospitable experience
# 1                        Awesome stay at Visnita county
# 2     Vismita County need to have a relook at the pr...
# 3                                         Awesome staff
# 4                                         Superb Resort
# ...                                                 ...
# 2036                                     Nice and clean
# 2037                        Neat hotel comfortable stay
# 2038                                    Value for money
# 2039                                 awesome experience
# 2040                    Pleasant and comfortable stay!!
#
#                                                  review  \
# 0     The ambience amidst nature was lovely and sere...
# 1     We stayed there for 3 days ..it's awesome expe...
# 2     The property is extremely pricey with respect ...
# 3     beautiful Vibes, the service staff extremely c...
# 4     Resort is Beutiful  with Lot's of Greenaries a...
# ...                                                 ...
# 2036  Nice and clean property in central Chickmaglur...
# 2037  We stayed in the family suite...which was very...
# 2038  Pros : Good complimentary breakfast, in terms ...
# 2039  Hi CrystalInn Team,  It was nice to stay with ...
# 2040  We (family of four) stayed here in the mid of ...
#
#                           Hotel_name  \
# 0                     Vismita County
# 1                     Vismita County
# 2                     Vismita County
# 3                     Vismita County
# 4                     Vismita County
# ...                              ...
# 2036  Genx Crystal Inn Chikmangaluru
# 2037  Genx Crystal Inn Chikmangaluru
# 2038  Genx Crystal Inn Chikmangaluru
# 2039  Genx Crystal Inn Chikmangaluru
# 2040  Genx Crystal Inn Chikmangaluru
#
#                                              review_new  \
# 0     Hospitable experience The ambience amidst natu...
# 1     Awesome stay at Visnita county We stayed there...
# 2     Vismita County need to have a relook at the pr...
# 3     Awesome staff beautiful Vibes, the service sta...
# 4     Superb Resort Resort is Beutiful  with Lot's o...
# ...                                                 ...
# 2036  Nice and clean Nice and clean property in cent...
# 2037  Neat hotel comfortable stay We stayed in the f...
# 2038  Value for money Pros : Good complimentary brea...
# 2039  awesome experience Hi CrystalInn Team,  It was...
# 2040  Pleasant and comfortable stay!! We (family of ...
#
#                                            clean_review
# 0     hospitable experience the ambience amidst natu...
# 1     awesome stay at visnita county we stayed there...
# 2     vismita county need to have a relook at the pr...
# 3     awesome staff beautiful vibes the service staf...
# 4     superb resort resort is beutiful  with lots of...
# ...                                                 ...
# 2036  nice and clean nice and clean property in cent...
# 2037  neat hotel comfortable stay we stayed in the f...
# 2038  value for money pros  good complimentary break...
# 2039  awesome experience hi crystalinn team  it was ...
# 2040  pleasant and comfortable stay we family of fou...
#
# [2035 rows x 5 columns]

# %%
#PART OF SPEECH TAGGING
pos_dict = {'J':wordnet.ADJ, 'V':wordnet.VERB, 'N':wordnet.NOUN, 'R':wordnet.ADV}
def token_stop_pos(text):
    tags = pos_tag(word_tokenize(text))
    newlist=[]
    for word, tag in tags:
        newlist.append(tuple([word, pos_dict.get(tag[0])]))
    return(newlist)

# %%
#Examples for POS tagging
print(token_stop_pos("The room was not clean"))
print(token_stop_pos("The staff was polite I had a comfortable stay"))
print(token_stop_pos("Rooms were extremely pricey"))
# Out:
# [('The', None), ('room', 'n'), ('was', 'v'), ('not', 'r'), ('clean', 'a')]
# [('The', None), ('staff', 'n'), ('was', 'v'), ('polite', 'a'), ('I', None), ('had', 'v'), ('a', None), ('comfortable', 'a'), ('stay', 'n')]
# [('Rooms', 'n'), ('were', 'v'), ('extremely', 'r'), ('pricey', 'a')]

# %%
review['POS tagged'] = review['clean_review'].apply(token_stop_pos)
review
# Out:
#                                                   title  \
# 0                                 Hospitable experience
# 1                        Awesome stay at Visnita county
# 2     Vismita County need to have a relook at the pr...
# 3                                         Awesome staff
# 4                                         Superb Resort
# ...                                                 ...
# 2036                                     Nice and clean
# 2037                        Neat hotel comfortable stay
# 2038                                    Value for money
# 2039                                 awesome experience
# 2040                    Pleasant and comfortable stay!!
#
#                                                  review  \
# 0     The ambience amidst nature was lovely and sere...
# 1     We stayed there for 3 days ..it's awesome expe...
# 2     The property is extremely pricey with respect ...
# 3     beautiful Vibes, the service staff extremely c...
# 4     Resort is Beutiful  with Lot's of Greenaries a...
# ...                                                 ...
# 2036  Nice and clean property in central Chickmaglur...
# 2037  We stayed in the family suite...which was very...
# 2038  Pros : Good complimentary breakfast, in terms ...
# 2039  Hi CrystalInn Team,  It was nice to stay with ...
# 2040  We (family of four) stayed here in the mid of ...
#
#                           Hotel_name  \
# 0                     Vismita County
# 1                     Vismita County
# 2                     Vismita County
# 3                     Vismita County
# 4                     Vismita County
# ...                              ...
# 2036  Genx Crystal Inn Chikmangaluru
# 2037  Genx Crystal Inn Chikmangaluru
# 2038  Genx Crystal Inn Chikmangaluru
# 2039  Genx Crystal Inn Chikmangaluru
# 2040  Genx Crystal Inn Chikmangaluru
#
#                                              review_new  \
# 0     Hospitable experience The ambience amidst natu...
# 1     Awesome stay at Visnita county We stayed there...
# 2     Vismita County need to have a relook at the pr...
# 3     Awesome staff beautiful Vibes, the service sta...
# 4     Superb Resort Resort is Beutiful  with Lot's o...
# ...                                                 ...
# 2036  Nice and clean Nice and clean property in cent...
# 2037  Neat hotel comfortable stay We stayed in the f...
# 2038  Value for money Pros : Good complimentary brea...
# 2039  awesome experience Hi CrystalInn Team,  It was...
# 2040  Pleasant and comfortable stay!! We (family of ...
#
#                                            clean_review  \
# 0     hospitable experience the ambience amidst natu...
# 1     awesome stay at visnita county we stayed there...
# 2     vismita county need to have a relook at the pr...
# 3     awesome staff beautiful vibes the service staf...
# 4     superb resort resort is beutiful  with lots of...
# ...                                                 ...
# 2036  nice and clean nice and clean property in cent...
# 2037  neat hotel comfortable stay we stayed in the f...
# 2038  value for money pros  good complimentary break...
# 2039  awesome experience hi crystalinn team  it was ...
# 2040  pleasant and comfortable stay we family of fou...
#
#                                              POS tagged
# 0     [(hospitable, a), (experience, n), (the, None)...
# 1     [(awesome, a), (stay, n), (at, None), (visnita...
# 2     [(vismita, a), (county, n), (need, n), (to, No...
# 3     [(awesome, a), (staff, n), (beautiful, a), (vi...
# 4     [(superb, n), (resort, n), (resort, n), (is, v...
# ...                                                 ...
# 2036  [(nice, a), (and, None), (clean, a), (nice, n)...
# 2037  [(neat, a), (hotel, n), (comfortable, a), (sta...
# 2038  [(value, n), (for, None), (money, n), (pros, n...
# 2039  [(awesome, a), (experience, n), (hi, n), (crys...
# 2040  [(pleasant, n), (and, None), (comfortable, a),...
#
# [2035 rows x 6 columns]

# %%
review['POS tagged'].describe()
review
# Out:
#                                                   title  \
# 0                                 Hospitable experience
# 1                        Awesome stay at Visnita county
# 2     Vismita County need to have a relook at the pr...
# 3                                         Awesome staff
# 4                                         Superb Resort
# ...                                                 ...
# 2036                                     Nice and clean
# 2037                        Neat hotel comfortable stay
# 2038                                    Value for money
# 2039                                 awesome experience
# 2040                    Pleasant and comfortable stay!!
#
#                                                  review  \
# 0     The ambience amidst nature was lovely and sere...
# 1     We stayed there for 3 days ..it's awesome expe...
# 2     The property is extremely pricey with respect ...
# 3     beautiful Vibes, the service staff extremely c...
# 4     Resort is Beutiful  with Lot's of Greenaries a...
# ...                                                 ...
# 2036  Nice and clean property in central Chickmaglur...
# 2037  We stayed in the family suite...which was very...
# 2038  Pros : Good complimentary breakfast, in terms ...
# 2039  Hi CrystalInn Team,  It was nice to stay with ...
# 2040  We (family of four) stayed here in the mid of ...
#
#                           Hotel_name  \
# 0                     Vismita County
# 1                     Vismita County
# 2                     Vismita County
# 3                     Vismita County
# 4                     Vismita County
# ...                              ...
# 2036  Genx Crystal Inn Chikmangaluru
# 2037  Genx Crystal Inn Chikmangaluru
# 2038  Genx Crystal Inn Chikmangaluru
# 2039  Genx Crystal Inn Chikmangaluru
# 2040  Genx Crystal Inn Chikmangaluru
#
#                                              review_new  \
# 0     Hospitable experience The ambience amidst natu...
# 1     Awesome stay at Visnita county We stayed there...
# 2     Vismita County need to have a relook at the pr...
# 3     Awesome staff beautiful Vibes, the service sta...
# 4     Superb Resort Resort is Beutiful  with Lot's o...
# ...                                                 ...
# 2036  Nice and clean Nice and clean property in cent...
# 2037  Neat hotel comfortable stay We stayed in the f...
# 2038  Value for money Pros : Good complimentary brea...
# 2039  awesome experience Hi CrystalInn Team,  It was...
# 2040  Pleasant and comfortable stay!! We (family of ...
#
#                                            clean_review  \
# 0     hospitable experience the ambience amidst natu...
# 1     awesome stay at visnita county we stayed there...
# 2     vismita county need to have a relook at the pr...
# 3     awesome staff beautiful vibes the service staf...
# 4     superb resort resort is beutiful  with lots of...
# ...                                                 ...
# 2036  nice and clean nice and clean property in cent...
# 2037  neat hotel comfortable stay we stayed in the f...
# 2038  value for money pros  good complimentary break...
# 2039  awesome experience hi crystalinn team  it was ...
# 2040  pleasant and comfortable stay we family of fou...
#
#                                              POS tagged
# 0     [(hospitable, a), (experience, n), (the, None)...
# 1     [(awesome, a), (stay, n), (at, None), (visnita...
# 2     [(vismita, a), (county, n), (need, n), (to, No...
# 3     [(awesome, a), (staff, n), (beautiful, a), (vi...
# 4     [(superb, n), (resort, n), (resort, n), (is, v...
# ...                                                 ...
# 2036  [(nice, a), (and, None), (clean, a), (nice, n)...
# 2037  [(neat, a), (hotel, n), (comfortable, a), (sta...
# 2038  [(value, n), (for, None), (money, n), (pros, n...
# 2039  [(awesome, a), (experience, n), (hi, n), (crys...
# 2040  [(pleasant, n), (and, None), (comfortable, a),...
#
# [2035 rows x 6 columns]

# %%
#Noun Removal and None tag Removal 
def RemoveNoun(a):
    res = ast.literal_eval(str(a))
    l=[]
    for key,val in res:
        if val!='n' and val!=None :
            l.append(key.lower())
    return l
review['POS tagg without Noun'] = review.apply(lambda row: RemoveNoun(row['POS tagged']), axis=1)

review
# Out:
#                                                   title  \
# 0                                 Hospitable experience
# 1                        Awesome stay at Visnita county
# 2     Vismita County need to have a relook at the pr...
# 3                                         Awesome staff
# 4                                         Superb Resort
# ...                                                 ...
# 2036                                     Nice and clean
# 2037                        Neat hotel comfortable stay
# 2038                                    Value for money
# 2039                                 awesome experience
# 2040                    Pleasant and comfortable stay!!
#
#                                                  review  \
# 0     The ambience amidst nature was lovely and sere...
# 1     We stayed there for 3 days ..it's awesome expe...
# 2     The property is extremely pricey with respect ...
# 3     beautiful Vibes, the service staff extremely c...
# 4     Resort is Beutiful  with Lot's of Greenaries a...
# ...                                                 ...
# 2036  Nice and clean property in central Chickmaglur...
# 2037  We stayed in the family suite...which was very...
# 2038  Pros : Good complimentary breakfast, in terms ...
# 2039  Hi CrystalInn Team,  It was nice to stay with ...
# 2040  We (family of four) stayed here in the mid of ...
#
#                           Hotel_name  \
# 0                     Vismita County
# 1                     Vismita County
# 2                     Vismita County
# 3                     Vismita County
# 4                     Vismita County
# ...                              ...
# 2036  Genx Crystal Inn Chikmangaluru
# 2037  Genx Crystal Inn Chikmangaluru
# 2038  Genx Crystal Inn Chikmangaluru
# 2039  Genx Crystal Inn Chikmangaluru
# 2040  Genx Crystal Inn Chikmangaluru
#
#                                              review_new  \
# 0     Hospitable experience The ambience amidst natu...
# 1     Awesome stay at Visnita county We stayed there...
# 2     Vismita County need to have a relook at the pr...
# 3     Awesome staff beautiful Vibes, the service sta...
# 4     Superb Resort Resort is Beutiful  with Lot's o...
# ...                                                 ...
# 2036  Nice and clean Nice and clean property in cent...
# 2037  Neat hotel comfortable stay We stayed in the f...
# 2038  Value for money Pros : Good complimentary brea...
# 2039  awesome experience Hi CrystalInn Team,  It was...
# 2040  Pleasant and comfortable stay!! We (family of ...
#
#                                            clean_review  \
# 0     hospitable experience the ambience amidst natu...
# 1     awesome stay at visnita county we stayed there...
# 2     vismita county need to have a relook at the pr...
# 3     awesome staff beautiful vibes the service staf...
# 4     superb resort resort is beutiful  with lots of...
# ...                                                 ...
# 2036  nice and clean nice and clean property in cent...
# 2037  neat hotel comfortable stay we stayed in the f...
# 2038  value for money pros  good complimentary break...
# 2039  awesome experience hi crystalinn team  it was ...
# 2040  pleasant and comfortable stay we family of fou...
#
#                                              POS tagged  \
# 0     [(hospitable, a), (experience, n), (the, None)...
# 1     [(awesome, a), (stay, n), (at, None), (visnita...
# 2     [(vismita, a), (county, n), (need, n), (to, No...
# 3     [(awesome, a), (staff, n), (beautiful, a), (vi...
# 4     [(superb, n), (resort, n), (resort, n), (is, v...
# ...                                                 ...
# 2036  [(nice, a), (and, None), (clean, a), (nice, n)...
# 2037  [(neat, a), (hotel, n), (comfortable, a), (sta...
# 2038  [(value, n), (for, None), (money, n), (pros, n...
# 2039  [(awesome, a), (experience, n), (hi, n), (crys...
# 2040  [(pleasant, n), (and, None), (comfortable, a),...
#
#                                   POS tagg without Noun
# 0     [hospitable, amidst, was, lovely, serene, was,...
# 1     [awesome, visnita, stayed, awesome, is, so, ca...
# 2     [vismita, have, pricing, is, extremely, pricey...
# 3     [awesome, beautiful, vibes, extremely, courteo...
# 4     [is, beutiful, was, large, required, amenities...
# ...                                                 ...
# 2036  [nice, clean, clean, central, have, small, ful...
# 2037  [neat, comfortable, stayed, was, very, neat, w...
# 2038  [good, complimentary, best, is, awesome, itali...
# 2039  [awesome, was, nice, stay, team, was, just, aw...
# 2040  [comfortable, here, had, very, pleasant, comfo...
#
# [2035 rows x 7 columns]

# %%
#Lemmatize
w_tokenizer = nltk.tokenize.WhitespaceTokenizer()
lemmatizer = nltk.WordNetLemmatizer()
def lemmatize_text(text):
    return [lemmatizer.lemmatize(w) for w in text]
review['final_review']=review['POS tagg without Noun'].apply(lambda x: " ".join(lemmatize_text(x)))
review
# Out:
#                                                   title  \
# 0                                 Hospitable experience
# 1                        Awesome stay at Visnita county
# 2     Vismita County need to have a relook at the pr...
# 3                                         Awesome staff
# 4                                         Superb Resort
# ...                                                 ...
# 2036                                     Nice and clean
# 2037                        Neat hotel comfortable stay
# 2038                                    Value for money
# 2039                                 awesome experience
# 2040                    Pleasant and comfortable stay!!
#
#                                                  review  \
# 0     The ambience amidst nature was lovely and sere...
# 1     We stayed there for 3 days ..it's awesome expe...
# 2     The property is extremely pricey with respect ...
# 3     beautiful Vibes, the service staff extremely c...
# 4     Resort is Beutiful  with Lot's of Greenaries a...
# ...                                                 ...
# 2036  Nice and clean property in central Chickmaglur...
# 2037  We stayed in the family suite...which was very...
# 2038  Pros : Good complimentary breakfast, in terms ...
# 2039  Hi CrystalInn Team,  It was nice to stay with ...
# 2040  We (family of four) stayed here in the mid of ...
#
#                           Hotel_name  \
# 0                     Vismita County
# 1                     Vismita County
# 2                     Vismita County
# 3                     Vismita County
# 4                     Vismita County
# ...                              ...
# 2036  Genx Crystal Inn Chikmangaluru
# 2037  Genx Crystal Inn Chikmangaluru
# 2038  Genx Crystal Inn Chikmangaluru
# 2039  Genx Crystal Inn Chikmangaluru
# 2040  Genx Crystal Inn Chikmangaluru
#
#                                              review_new  \
# 0     Hospitable experience The ambience amidst natu...
# 1     Awesome stay at Visnita county We stayed there...
# 2     Vismita County need to have a relook at the pr...
# 3     Awesome staff beautiful Vibes, the service sta...
# 4     Superb Resort Resort is Beutiful  with Lot's o...
# ...                                                 ...
# 2036  Nice and clean Nice and clean property in cent...
# 2037  Neat hotel comfortable stay We stayed in the f...
# 2038  Value for money Pros : Good complimentary brea...
# 2039  awesome experience Hi CrystalInn Team,  It was...
# 2040  Pleasant and comfortable stay!! We (family of ...
#
#                                            clean_review  \
# 0     hospitable experience the ambience amidst natu...
# 1     awesome stay at visnita county we stayed there...
# 2     vismita county need to have a relook at the pr...
# 3     awesome staff beautiful vibes the service staf...
# 4     superb resort resort is beutiful  with lots of...
# ...                                                 ...
# 2036  nice and clean nice and clean property in cent...
# 2037  neat hotel comfortable stay we stayed in the f...
# 2038  value for money pros  good complimentary break...
# 2039  awesome experience hi crystalinn team  it was ...
# 2040  pleasant and comfortable stay we family of fou...
#
#                                              POS tagged  \
# 0     [(hospitable, a), (experience, n), (the, None)...
# 1     [(awesome, a), (stay, n), (at, None), (visnita...
# 2     [(vismita, a), (county, n), (need, n), (to, No...
# 3     [(awesome, a), (staff, n), (beautiful, a), (vi...
# 4     [(superb, n), (resort, n), (resort, n), (is, v...
# ...                                                 ...
# 2036  [(nice, a), (and, None), (clean, a), (nice, n)...
# 2037  [(neat, a), (hotel, n), (comfortable, a), (sta...
# 2038  [(value, n), (for, None), (money, n), (pros, n...
# 2039  [(awesome, a), (experience, n), (hi, n), (crys...
# 2040  [(pleasant, n), (and, None), (comfortable, a),...
#
#                                   POS tagg without Noun  \
# 0     [hospitable, amidst, was, lovely, serene, was,...
# 1     [awesome, visnita, stayed, awesome, is, so, ca...
# 2     [vismita, have, pricing, is, extremely, pricey...
# 3     [awesome, beautiful, vibes, extremely, courteo...
# 4     [is, beutiful, was, large, required, amenities...
# ...                                                 ...
# 2036  [nice, clean, clean, central, have, small, ful...
# 2037  [neat, comfortable, stayed, was, very, neat, w...
# 2038  [good, complimentary, best, is, awesome, itali...
# 2039  [awesome, was, nice, stay, team, was, just, aw...
# 2040  [comfortable, here, had, very, pleasant, comfo...
#
#                                            final_review
# 0     hospitable amidst wa lovely serene wa very fri...
# 1     awesome visnita stayed awesome is so calm beau...
# 2     vismita have pricing is extremely pricey espec...
# 3     awesome beautiful vibe extremely courteous wa ...
# 4     is beutiful wa large required amenity extremel...
# ...                                                 ...
# 2036  nice clean clean central have small full is ne...
# 2037  neat comfortable stayed wa very neat well main...
# 2038  good complimentary best is awesome italian con...
# 2039  awesome wa nice stay team wa just awesome serv...
# 2040  comfortable here had very pleasant comfortable...
#
# [2035 rows x 8 columns]

# %%
df_analysis = pd.DataFrame()
df_analysis=review[["final_review","Hotel_name"]]
df_analysis
# Out:
#                                            final_review  \
# 0     hospitable amidst wa lovely serene wa very fri...
# 1     awesome visnita stayed awesome is so calm beau...
# 2     vismita have pricing is extremely pricey espec...
# 3     awesome beautiful vibe extremely courteous wa ...
# 4     is beutiful wa large required amenity extremel...
# ...                                                 ...
# 2036  nice clean clean central have small full is ne...
# 2037  neat comfortable stayed wa very neat well main...
# 2038  good complimentary best is awesome italian con...
# 2039  awesome wa nice stay team wa just awesome serv...
# 2040  comfortable here had very pleasant comfortable...
#
#                           Hotel_name
# 0                     Vismita County
# 1                     Vismita County
# 2                     Vismita County
# 3                     Vismita County
# 4                     Vismita County
# ...                              ...
# 2036  Genx Crystal Inn Chikmangaluru
# 2037  Genx Crystal Inn Chikmangaluru
# 2038  Genx Crystal Inn Chikmangaluru
# 2039  Genx Crystal Inn Chikmangaluru
# 2040  Genx Crystal Inn Chikmangaluru
#
# [2035 rows x 2 columns]

# %%
from nltk.probability import FreqDist
corpus = ' '.join(df_analysis['final_review'])
# Tokenize the corpus into words
tokens = word_tokenize(corpus)

# Calculate the frequency distribution of words
fdist = FreqDist(tokens)

# Create a DataFrame from the frequency distribution
freq_df = pd.DataFrame(fdist.items(), columns=['Word', 'Frequency']).sort_values(by='Frequency', ascending=False)
freq_df.head(60)
# Out:
#             Word  Frequency
# 28            is       3368
# 2             wa       2807
# 5           very       2061
# 45          good       1873
# 193          are       1557
# 36          were       1174
# 19           not        890
# 78           had        800
# 83         great        753
# 33          have        748
# 118         well        632
# 102           be        535
# 132         nice        503
# 72          best        502
# 21         clean        495
# 67     excellent        486
# 211         also        486
# 29            so        406
# 124         stay        403
# 77       amazing        402
# 31     beautiful        395
# 112       really        365
# 9             ha        344
# 164            i        338
# 119   maintained        337
# 82          just        326
# 27        stayed        322
# 6       friendly        314
# 184        visit        306
# 311         only        296
# 25       awesome        284
# 84          here        270
# 195      helpful        259
# 47          more        253
# 156        other        240
# 125        again        232
# 111          get        227
# 85            go        225
# 134  comfortable        224
# 122      enjoyed        223
# 80     wonderful        219
# 37       overall        218
# 53     courteous        217
# 117      located        215
# 407          too        204
# 128         even        202
# 68     recommend        200
# 169         much        200
# 248          out        199
# 321        there        197
# 14          made        196
# 104     spacious        193
# 456         away        189
# 162      visited        184
# 60    definitely        184
# 38       vismita        183
# 336           do        180
# 10          been        179
# 48          make        178
# 86          back        175

# %%
#Create a custom list of words that are meaningless for analysis
stopwords1=["is","wa","very","are","not","great","also","so","just","only","were","had","have","be","ha","i","visit","here","other","get","go","there","do","away","overall","too","much","out","made","vimita","been","make","back"]

# %%
def SentimentAnalyzer(text):
    sid_obj= SentimentIntensityAnalyzer()
    return(sid_obj.polarity_scores(text)) 
df_analysis["polarity_score"]=df_analysis["final_review"].apply(SentimentAnalyzer)

# %%
def get(dict):
    return(dict.get("compound"))
def analysis(score):
    if score<=-0.05:
        return("negative")
    elif score>=0.05:
        return("positive")
    else:
        return("neutral")
df_analysis["compound"]=df_analysis.polarity_score.apply(get)
df_analysis["emotion"]=df_analysis.compound.apply(analysis)
df_analysis
# Out:
#                                            final_review  \
# 0     hospitable amidst wa lovely serene wa very fri...
# 1     awesome visnita stayed awesome is so calm beau...
# 2     vismita have pricing is extremely pricey espec...
# 3     awesome beautiful vibe extremely courteous wa ...
# 4     is beutiful wa large required amenity extremel...
# ...                                                 ...
# 2036  nice clean clean central have small full is ne...
# 2037  neat comfortable stayed wa very neat well main...
# 2038  good complimentary best is awesome italian con...
# 2039  awesome wa nice stay team wa just awesome serv...
# 2040  comfortable here had very pleasant comfortable...
#
#                           Hotel_name  \
# 0                     Vismita County
# 1                     Vismita County
# 2                     Vismita County
# 3                     Vismita County
# 4                     Vismita County
# ...                              ...
# 2036  Genx Crystal Inn Chikmangaluru
# 2037  Genx Crystal Inn Chikmangaluru
# 2038  Genx Crystal Inn Chikmangaluru
# 2039  Genx Crystal Inn Chikmangaluru
# 2040  Genx Crystal Inn Chikmangaluru
#
#                                          polarity_score  compound   emotion
# 0     {'neg': 0.047, 'neu': 0.416, 'pos': 0.537, 'co...    0.9702  positive
# 1     {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'comp...    0.9780  positive
# 2     {'neg': 0.066, 'neu': 0.696, 'pos': 0.238, 'co...    0.6901  positive
# 3     {'neg': 0.0, 'neu': 0.2, 'pos': 0.8, 'compound...    0.9749  positive
# 4     {'neg': 0.0, 'neu': 0.335, 'pos': 0.665, 'comp...    0.9575  positive
# ...                                                 ...       ...       ...
# 2036  {'neg': 0.0, 'neu': 0.232, 'pos': 0.768, 'comp...    0.9764  positive
# 2037  {'neg': 0.0, 'neu': 0.348, 'pos': 0.652, 'comp...    0.9616  positive
# 2038  {'neg': 0.0, 'neu': 0.362, 'pos': 0.638, 'comp...    0.9788  positive
# 2039  {'neg': 0.0, 'neu': 0.404, 'pos': 0.596, 'comp...    0.9451  positive
# 2040  {'neg': 0.0, 'neu': 0.447, 'pos': 0.553, 'comp...    0.9439  positive
#
# [2035 rows x 5 columns]

# %%
df_analysis.emotion.value_counts()
# Out:
# positive    1921
# negative     107
# neutral        7
# Name: emotion, dtype: int64

# %%
# Group by hotel_name and review_sentiment and then unstack to pivot sentiment values as columns
grouped = df_analysis.groupby(['Hotel_name', 'emotion']).size().unstack(fill_value=0)

# Rename the columns
grouped.columns = ['negative', 'neutral', 'positive']

# Reset index to make hotel_name a column
result_df = grouped.reset_index()

# Calculate the total reviews for each hotel
result_df['total_reviews'] = result_df['positive'] + result_df['negative'] + result_df['neutral']

# Calculate the average percentage of positive, negative, and neutral reviews
result_df['avg_positive'] = (result_df['positive'] / result_df['total_reviews']) 
result_df['avg_negative'] = (result_df['negative'] / result_df['total_reviews']) 
result_df['avg_neutral'] = (result_df['neutral'] / result_df['total_reviews'])
result_df
# Out:
#                             Hotel_name  negative  neutral  positive  \
# 0                              Aadrika        10        0       254
# 1                Chikmagalur Golf Club         3        0        28
# 2       Genx Crystal Inn Chikmangaluru         6        0        54
# 3                  Good Earth Homestay         2        0        37
# 4                    Green wood Resort         4        2        66
# 5   Honeydewwz Exoticaa Hotel & Resort         1        0       106
# 6               Kalgreen Valley Resort         3        1        82
# 7                            Kerehaklu         1        0       147
# 8                 Silent Valley Resort        39        2       165
# 9   The River Tern Lodge Jungle Lodges        10        0       345
# 10           Treebo Trend Maharaja Inn         5        0        93
# 11                Treebo Trend Sunrise        22        2        88
# 12                      Vismita County         1        0       456
#
#     total_reviews  avg_positive  avg_negative  avg_neutral
# 0             264      0.962121      0.037879     0.000000
# 1              31      0.903226      0.096774     0.000000
# 2              60      0.900000      0.100000     0.000000
# 3              39      0.948718      0.051282     0.000000
# 4              72      0.916667      0.055556     0.027778
# 5             107      0.990654      0.009346     0.000000
# 6              86      0.953488      0.034884     0.011628
# 7             148      0.993243      0.006757     0.000000
# 8             206      0.800971      0.189320     0.009709
# 9             355      0.971831      0.028169     0.000000
# 10             98      0.948980      0.051020     0.000000
# 11            112      0.785714      0.196429     0.017857
# 12            457      0.997812      0.002188     0.000000

# %%
# Filter dataframe to include only positive reviews
positive_reviews = df_analysis[df_analysis['emotion'] == 'positive']

# Combine all reviews into a single string
all_reviews = ' '.join(positive_reviews['final_review'])

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white',stopwords=stopwords1).generate(all_reviews)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Filter dataframe to include only positive reviews
negative_reviews = df_analysis[df_analysis['emotion'] == 'negative']

# Combine all reviews into a single string
all_reviews = ' '.join(negative_reviews['final_review'])

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white',stopwords=stopwords1).generate(all_reviews)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
